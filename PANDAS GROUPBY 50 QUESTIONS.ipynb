# %%
import pandas as pd
import numpy as np

# %%
survey=pd.read_csv("survey_results_public.csv",index_col=[0])

# %%
survey
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# # (1) to get country by details of people satisfied in their job

# %%
job_sat=survey.groupby("JobSat")

# %%
job_sat["Country"].value_counts()
# Out:
# JobSat                              Country
# Neither satisfied nor dissatisfied  United States           1524
#                                     India                   1272
#                                     Germany                  523
#                                     United Kingdom           514
#                                     Canada                   278
#                                                             ...
# Very satisfied                      Oman                       1
#                                     San Marino                 1
#                                     Swaziland                  1
#                                     Syrian Arab Republic       1
#                                     Timor-Leste                1
# Name: Country, Length: 707, dtype: int64

# %% [markdown]
# # (2)calculate the mean of a numeric column within each group.

# %%
country_group=survey.groupby("Country")

# %%
country_group["ConvertedComp"].mean()
# Out:
# Country
# Afghanistan                             101953.333333
# Albania                                  21833.700000
# Algeria                                  34924.047619
# Andorra                                 160931.000000
# Angola                                    7764.000000
#                                             ...
# Venezuela, Bolivarian Republic of...     14581.627907
# Viet Nam                                 17233.436782
# Yemen                                    16909.166667
# Zambia                                   10075.375000
# Zimbabwe                                 34046.666667
# Name: ConvertedComp, Length: 179, dtype: float64

# %% [markdown]
# # (3)Find the total count of records in each group

# %%
country_group["Student"].get_group("India").value_counts()
# Out:
# No                5443
# Yes, full-time    2944
# Yes, part-time     318
# Name: Student, dtype: int64

# %% [markdown]
# # (4)Calculate the maximum value in a different column for each group.

# %%
country_group["ConvertedComp"].get_group("India").max()
# Out:
# 2000000.0

# %% [markdown]
# # (5)Group data by multiple columns and calculate the sum of a numeric column.

# %%
country_group["ConvertedComp"].get_group("India").sum()
# Out:
# 112202602.0

# %% [markdown]
# # 6.	Calculate the average values of multiple columns for each group.

# %%
job_sat["ConvertedComp"].mean()
# Out:
# JobSat
# Neither satisfied nor dissatisfied    106379.734029
# Slightly dissatisfied                 110360.994075
# Slightly satisfied                    123414.081801
# Very dissatisfied                     120739.585703
# Very satisfied                        147949.915596
# Name: ConvertedComp, dtype: float64

# %%
job_sat["ConvertedComp"].get_group("Very satisfied").mean()
# Out:
# 147949.9155960228

# %% [markdown]
# # 7.	Group data by a column and calculate the median of a different column within each group.

# %%
country_group["ConvertedComp"].get_group("India").median()
# Out:
# 10080.0

# %% [markdown]
# # 8.	Calculate the sum of a numeric column and rename the resulting column.

# %%
survey.rename(columns={"ConvertedComp":"Salary"})
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
country_group["ConvertedComp"].get_group("Australia").sum()
# Out:
# 213911772.0

# %% [markdown]
# # 9.	Filter out groups with a minimum count of records

# %%
employ_group=survey.groupby("Employment")

# %%
employ_group["Age"].min()
# Out:
# Employment
# Employed full-time                                      1.0
# Employed part-time                                      2.0
# Independent contractor, freelancer, or self-employed    1.0
# Not employed, and not looking for work                  1.0
# Not employed, but looking for work                      2.0
# Retired                                                 5.0
# Name: Age, dtype: float64

# %% [markdown]
# # 10.	Keep only groups with a mean value above a certain threshold.

# %%
job_sat["ConvertedComp"].mean()>120000
# Out:
# JobSat
# Neither satisfied nor dissatisfied    False
# Slightly dissatisfied                 False
# Slightly satisfied                     True
# Very dissatisfied                      True
# Very satisfied                         True
# Name: ConvertedComp, dtype: bool

# %% [markdown]
# # 11.group the data and sort the result by mean values.

# %%
country_group["ConvertedComp"].mean().sort_values()
# Out:
# Country
# Gabon                       0.0
# Guinea                   1956.0
# Syrian Arab Republic     3562.5
# Burundi                  3606.0
# Togo                     4188.0
#                           ...
# Papua New Guinea            NaN
# Saint Kitts and Nevis       NaN
# Sao Tome and Principe       NaN
# Sierra Leone                NaN
# Tonga                       NaN
# Name: ConvertedComp, Length: 179, dtype: float64

# %% [markdown]
# # 12.	Sort groups in descending order by the maximum value within each group.

# %%
country_group["ConvertedComp"].max().sort_values()
# Out:
# Country
# Gabon                                  0.0
# Guinea                              1956.0
# Togo                                4188.0
# Burundi                             4272.0
# Lao People's Democratic Republic    5604.0
#                                      ...
# Papua New Guinea                       NaN
# Saint Kitts and Nevis                  NaN
# Sao Tome and Principe                  NaN
# Sierra Leone                           NaN
# Tonga                                  NaN
# Name: ConvertedComp, Length: 179, dtype: float64

# %% [markdown]
# # 13.	Group data and apply a custom function for aggregation.

# %%
country_group["ConvertedComp"].describe()
# Out:
#                                       count           mean            std  \
# Country
# Afghanistan                            12.0  101953.333333  285995.241798
# Albania                                50.0   21833.700000   31450.766680
# Algeria                                42.0   34924.047619  152933.628015
# Andorra                                 2.0  160931.000000   15458.768450
# Angola                                  1.0    7764.000000            NaN
# ...                                     ...            ...            ...
# Venezuela, Bolivarian Republic of...   43.0   14581.627907   24218.759814
# Viet Nam                               87.0   17233.436782   19921.575978
# Yemen                                   6.0   16909.166667   21847.429143
# Zambia                                  8.0   10075.375000   13200.366434
# Zimbabwe                               15.0   34046.666667   44166.969990
#
# ...

# %% [markdown]
# # 14.

# %%
job_sat["ConvertedComp"].describe()
# Out:
#                                       count           mean            std  \
# JobSat
# Neither satisfied nor dissatisfied   6230.0  106379.734029  260559.191910
# Slightly dissatisfied                8608.0  110360.994075  259040.156744
# Slightly satisfied                  19193.0  123414.081801  280543.798460
# Very dissatisfied                    3833.0  120739.585703  280438.569449
# Very satisfied                      17902.0  147949.915596  306425.125907
#
#                                     min      25%      50%       75%        max
# JobSat
# Neither satisfied nor dissatisfied  0.0  16500.0  42612.0   82141.0  2000000.0
# Slightly dissatisfied               0.0  19668.0  47120.5   86000.0  2000000.0
# Slightly satisfied                  0.0  25272.0  54964.0   95000.0  2000000.0
# Very dissatisfied                   0.0  20244.0  50413.0   95000.0  2000000.0
# Very satisfied                      0.0  37473.0  70000.0  120000.0  2000000.0

# %% [markdown]
# # 15.

# %%
survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
job_sat["Student"].value_counts()
# Out:
# JobSat                              Student
# Neither satisfied nor dissatisfied  No                 6766
#                                     Yes, full-time     1214
#                                     Yes, part-time      543
# Slightly dissatisfied               No                 8844
#                                     Yes, full-time     1102
#                                     Yes, part-time      680
# Slightly satisfied                  No                19996
#                                     Yes, full-time     2472
#                                     Yes, part-time     1451
# Very dissatisfied                   No                 3970
#                                     Yes, full-time      518
#                                     Yes, part-time      301
# Very satisfied                      No                18956
#                                     Yes, full-time     2109
#                                     Yes, part-time     1192
# ...

# %% [markdown]
# # 16.

# %%
country_group["SocialMedia"].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: SocialMedia, Length: 1220, dtype: int64

# %% [markdown]
# # 17.

# %%
job_sat["SocialMedia"].describe()
# Out:
#                                     count unique       top  freq
# JobSat
# Neither satisfied nor dissatisfied   8313     14  WhatsApp  1443
# Slightly dissatisfied               10284     14  WhatsApp  1690
# Slightly satisfied                  23242     14    Reddit  4104
# Very dissatisfied                    4602     14  WhatsApp   763
# Very satisfied                      21474     14    Reddit  4222

# %% [markdown]
# # 18.

# %%
country_group["SocialMedia"].describe()
# Out:
#                                      count unique                       top  \
# Country
# Afghanistan                             37      7                  Facebook
# Albania                                 84     10                  WhatsApp
# Algeria                                124      8                   YouTube
# Andorra                                  7      5  I don't use social media
# Angola                                   4      3                   Twitter
# ...                                    ...    ...                       ...
# Venezuela, Bolivarian Republic of...    85      8                  WhatsApp
# Viet Nam                               222      9                  Facebook
# Yemen                                   19      4                  WhatsApp
# Zambia                                  12      6                  Facebook
# Zimbabwe                                39      7                  WhatsApp
#
#                                      freq
# ...

# %% [markdown]
# # 19.

# %%
country_group["SocialMedia"].get_group("India")
# Out:
# Respondent
# 8                         YouTube
# 10                        YouTube
# 15                        YouTube
# 50                        YouTube
# 65                       WhatsApp
#                    ...
# 77339                     YouTube
# 79795                   Instagram
# 83862                     Twitter
# 84299                    LinkedIn
# 86012    I don't use social media
# Name: SocialMedia, Length: 9061, dtype: object

# %% [markdown]
# # 20.

# %%
job_sat["LanguageWorkedWith"].value_counts()
# Out:
# JobSat                              LanguageWorkedWith
# Neither satisfied nor dissatisfied  HTML/CSS;JavaScript;PHP;SQL              173
#                                     C#;HTML/CSS;JavaScript;SQL               156
#                                     Java                                     116
#                                     C#;HTML/CSS;JavaScript;SQL;TypeScript    113
#                                     HTML/CSS;JavaScript;PHP                  111
#                                                                             ...
# Very satisfied                      Scala;TypeScript                           1
#                                     Swift;Other(s):                            1
#                                     Swift;VBA                                  1
#                                     TypeScript;Other(s):                       1
#                                     WebAssembly                                1
# ...

# %% [markdown]
# # 21.

# %%
job_sat["LanguageWorkedWith"].get_group("Very satisfied").str.contains("Python").value_counts()
# Out:
# False    13099
# True      9220
# Name: LanguageWorkedWith, dtype: int64

# %% [markdown]
# # 22.

# %%
job_sat["LanguageWorkedWith"].get_group("Very satisfied").str.contains("Python").value_counts(normalize=True)
# Out:
# False    0.586899
# True     0.413101
# Name: LanguageWorkedWith, dtype: float64

# %% [markdown]
# # 23.

# %%
job_sat["LanguageWorkedWith"].get_group("Very satisfied").str.contains("HTML").value_counts()
# Out:
# True     14093
# False     8226
# Name: LanguageWorkedWith, dtype: int64

# %% [markdown]
# # 24.

# %%
country_group["Gender"].value_counts()
# Out:
# Country      Gender
# Afghanistan  Man                                                            26
#              Woman                                                           2
#              Non-binary, genderqueer, or gender non-conforming               1
#              Woman;Man;Non-binary, genderqueer, or gender non-conforming     1
# Albania      Man                                                            70
#                                                                             ..
# Yemen        Woman;Man                                                       1
# Zambia       Man                                                            11
#              Woman                                                           1
# Zimbabwe     Man                                                            37
#              Woman                                                           2
# Name: Gender, Length: 539, dtype: int64

# %% [markdown]
# # 25.

# %%
exp_group=survey.groupby("YearsCode")

# %%
exp_group["ConvertedComp"].value_counts()
# Out:
# YearsCode           ConvertedComp
# 1                   60000.0          10
#                     65000.0           9
#                     2520.0            7
#                     2000000.0         7
#                     45000.0           6
#                                      ..
# More than 50 years  154676.0          1
#                     180000.0          1
#                     250000.0          1
#                     628068.0          1
#                     785083.0          1
# Name: ConvertedComp, Length: 29825, dtype: int64

# %% [markdown]
# # 26.

# %%
exp_group["Gender"].value_counts()
# Out:
# YearsCode           Gender
# 1                   Man                                                            1438
#                     Woman                                                           242
#                     Non-binary, genderqueer, or gender non-conforming                13
#                     Woman;Man                                                         8
#                     Man;Non-binary, genderqueer, or gender non-conforming             6
#                                                                                    ...
# Less than 1 year    Woman;Man;Non-binary, genderqueer, or gender non-conforming       2
# More than 50 years  Man                                                             104
#                     Woman                                                             4
#                     Woman;Man;Non-binary, genderqueer, or gender non-conforming       3
# ...

# %% [markdown]
# # 27.

# %%
exp_group["Gender"].get_group("1").value_counts()
# Out:
# Man                                                            1438
# Woman                                                           242
# Non-binary, genderqueer, or gender non-conforming                13
# Woman;Man                                                         8
# Man;Non-binary, genderqueer, or gender non-conforming             6
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       5
# Woman;Non-binary, genderqueer, or gender non-conforming           4
# Name: Gender, dtype: int64

# %% [markdown]
# # 28.

# %%
exp_group["ConvertedComp"].get_group("1").value_counts()
# Out:
# 60000.0      10
# 65000.0       9
# 2520.0        7
# 2000000.0     7
# 50000.0       6
#              ..
# 150000.0      1
# 18319.0       1
# 105000.0      1
# 15120.0       1
# 19236.0       1
# Name: ConvertedComp, Length: 306, dtype: int64

# %% [markdown]
# # 29.

# %%
exp_group["ConvertedComp"].get_group("1").describe()
# Out:
# count    4.290000e+02
# mean     7.676522e+04
# std      2.704118e+05
# min      0.000000e+00
# 25%      6.780000e+03
# 50%      2.317200e+04
# 75%      5.000000e+04
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# # 30.

# %%
exp_group["ConvertedComp"].describe()
# Out:
#                      count           mean            std      min        25%  \
# YearsCode
# 1                    429.0   76765.221445  270411.848903      0.0    6780.00
# 10                  4896.0  116366.401757  270680.711207      0.0   25187.00
# 11                  1723.0  116627.448636  253562.989486      0.0   28728.00
# 12                  2666.0  122487.049887  265219.041033      0.0   31815.00
# 13                  1574.0  126944.614358  266671.968203      0.0   34372.00
# 14                  1636.0  131264.069071  273728.848118      0.0   35937.00
# 15                  3016.0  140741.923740  294409.939018      0.0   38697.00
# 16                  1246.0  145357.642857  289742.186632      0.0   42513.00
# 17                  1086.0  154208.909761  298156.346675      0.0   44710.25
# 18                  1466.0  148457.449523  277969.029185      0.0   47634.00
# 19                   788.0  171080.491117  341410.030698      4.0   49425.00
# ...

# %% [markdown]
# # 32.

# %%
job_sat["Gender"].value_counts()
# Out:
# JobSat                              Gender
# Neither satisfied nor dissatisfied  Man                                                             7757
#                                     Woman                                                            493
#                                     Non-binary, genderqueer, or gender non-conforming                 51
#                                     Man;Non-binary, genderqueer, or gender non-conforming             16
#                                     Woman;Non-binary, genderqueer, or gender non-conforming           13
#                                     Woman;Man                                                         10
#                                     Woman;Man;Non-binary, genderqueer, or gender non-conforming        7
# Slightly dissatisfied               Man                                                             9608
# ...

# %% [markdown]
# # 33.

# %%
job_sat["Age"].mean()
# Out:
# JobSat
# Neither satisfied nor dissatisfied    30.696049
# Slightly dissatisfied                 31.476800
# Slightly satisfied                    31.177632
# Very dissatisfied                     32.135354
# Very satisfied                        31.966638
# Name: Age, dtype: float64

# %% [markdown]
# # 34.

# %%
job_sat["Age"].value_counts()
# Out:
# JobSat                              Age
# Neither satisfied nor dissatisfied  26.0    534
#                                     27.0    512
#                                     25.0    505
#                                     28.0    483
#                                     24.0    480
#                                            ...
# Very satisfied                      77.0      1
#                                     79.0      1
#                                     84.0      1
#                                     90.0      1
#                                     98.0      1
# Name: Age, Length: 344, dtype: int64

# %% [markdown]
# # 35.

# %%
exp_group["PlatformWorkedWith"].value_counts()
# Out:
# YearsCode           PlatformWorkedWith
# 1                   Windows                    227
#                     Android                     87
#                     Linux;Windows               63
#                     Linux                       56
#                     WordPress                   51
#                                               ...
# More than 50 years  Microsoft Azure              1
#                     Microsoft Azure;Windows      1
#                     Windows;WordPress            1
#                     iOS;Linux;MacOS              1
#                     iOS;MacOS;WordPress          1
# Name: PlatformWorkedWith, Length: 29576, dtype: int64

# %% [markdown]
# # 36.

# %%
exp_group["PlatformWorkedWith"].describe()
# Out:
#                    count unique                 top freq
# YearsCode
# 1                   1382    415             Windows  227
# 10                  6269   1937             Windows  470
# 11                  2140    903             Windows  167
# 12                  3284   1288             Windows  241
# 13                  1905    783             Windows  141
# 14                  1993    850             Windows  146
# 15                  3700   1325             Windows  297
# 16                  1507    743             Windows  110
# 17                  1272    577             Windows  119
# 18                  1787    771             Windows  147
# 19                   951    476             Windows   75
# 2                   3258    923             Windows  419
# 20                  3417   1255             Windows  272
# 21                   676    371             Windows   52
# 22                   965    477             Windows   76
# ...

# %% [markdown]
# # 37.

# %%
edlevel=survey.groupby("EdLevel")

# %%
edlevel["ConvertedComp"].median()
# Out:
# EdLevel
# Associate degree                                                                      56092.5
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              60000.0
# I never completed any formal education                                                53562.0
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           57744.0
# Other doctoral degree (Ph.D, Ed.D., etc.)                                             81960.0
# Primary/elementary school                                                             34368.0
# Professional degree (JD, MD, etc.)                                                    32998.0
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    37128.0
# Some college/university study without earning a degree                                52476.0
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# # 38.

# %%
edlevel["ConvertedComp"].describe()
# Out:
#                                                       count           mean  \
# EdLevel
# Associate degree                                     1860.0  146191.275269
# Bachelor’s degree (BA, BS, B.Eng., etc.)            27063.0  134966.131508
# I never completed any formal education                220.0  154087.313636
# Master’s degree (MA, MS, M.Eng., MBA, etc.)         13826.0  120712.385650
# Other doctoral degree (Ph.D, Ed.D., etc.)            1699.0  171504.379046
# Primary/elementary school                             260.0   95072.546154
# Professional degree (JD, MD, etc.)                    745.0   86490.193289
# Secondary school (e.g. American high school, Ge...   2823.0   85330.023734
# Some college/university study without earning a...   6496.0  117587.731065
#
#                                                               std  min  \
# EdLevel
# Associate degree                                    348833.707803  0.0
# ...

# %% [markdown]
# # 39.

# %%
edlevel["ConvertedComp"].value_counts()
# Out:
# EdLevel                                                 ConvertedComp
# Associate degree                                        2000000.0        47
#                                                         1000000.0        23
#                                                         60000.0          21
#                                                         80000.0          20
#                                                         70000.0          19
#                                                                          ..
# Some college/university study without earning a degree  1668000.0         1
#                                                         1680000.0         1
#                                                         1740000.0         1
#                                                         1752000.0         1
#                                                         1965600.0         1
# Name: ConvertedComp, Length: 16696, dtype: int64

# %% [markdown]
# # 40.

# %%
edlevel["Gender"].describe()
# Out:
#                                                     count unique  top   freq
# EdLevel
# Associate degree                                     2836      7  Man   2595
# Bachelor’s degree (BA, BS, B.Eng., etc.)            37837      7  Man  34279
# I never completed any formal education                504      7  Man    419
# Master’s degree (MA, MS, M.Eng., MBA, etc.)         18929      7  Man  17275
# Other doctoral degree (Ph.D, Ed.D., etc.)            2315      6  Man   2101
# Primary/elementary school                            1353      7  Man   1275
# Professional degree (JD, MD, etc.)                   1155      7  Man   1064
# Secondary school (e.g. American high school, Ge...   8324      7  Man   7739
# Some college/university study without earning a...  10199      7  Man   9427

# %% [markdown]
# # 41.

# %%
edlevel["Gender"].value_counts()
# Out:
# EdLevel                                                 Gender
# Associate degree                                        Man                                                            2595
#                                                         Woman                                                           196
#                                                         Non-binary, genderqueer, or gender non-conforming                24
#                                                         Woman;Man;Non-binary, genderqueer, or gender non-conforming       8
#                                                         Man;Non-binary, genderqueer, or gender non-conforming             7
#                                                                                                                        ...
# Some college/university study without earning a degree  Non-binary, genderqueer, or gender non-conforming               105
# ...

# %% [markdown]
# # 42.

# %%
edlevel["Age"].min()
# Out:
# EdLevel
# Associate degree                                                                       4.0
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                               1.0
# I never completed any formal education                                                 1.0
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                            1.0
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              1.0
# Primary/elementary school                                                              1.0
# Professional degree (JD, MD, etc.)                                                    16.0
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     1.0
# Some college/university study without earning a degree                                 1.0
# Name: Age, dtype: float64

# %% [markdown]
# # 43.

# %%
edlevel["Age"].max()
# Out:
# EdLevel
# Associate degree                                                                      99.0
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              99.0
# I never completed any formal education                                                99.0
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           99.0
# Other doctoral degree (Ph.D, Ed.D., etc.)                                             99.0
# Primary/elementary school                                                             98.0
# Professional degree (JD, MD, etc.)                                                    78.0
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    99.0
# Some college/university study without earning a degree                                99.0
# Name: Age, dtype: float64

# %% [markdown]
# # 44.

# %%
edlevel["ConvertedComp"].var()
# Out:
# EdLevel
# Associate degree                                                                      1.216850e+11
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              9.373762e+10
# I never completed any formal education                                                1.108580e+11
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           6.267274e+10
# Other doctoral degree (Ph.D, Ed.D., etc.)                                             8.842570e+10
# Primary/elementary school                                                             5.849767e+10
# Professional degree (JD, MD, etc.)                                                    5.143835e+10
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    4.045857e+10
# Some college/university study without earning a degree                                7.248381e+10
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# # 45.

# %%
edlevel["ConvertedComp"].std()
# Out:
# EdLevel
# Associate degree                                                                      348833.707803
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              306166.003842
# I never completed any formal education                                                332953.395560
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           250345.235481
# Other doctoral degree (Ph.D, Ed.D., etc.)                                             297364.590072
# Primary/elementary school                                                             241862.925050
# Professional degree (JD, MD, etc.)                                                    226800.244943
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    201143.152706
# Some college/university study without earning a degree                                269228.179452
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# # 46.

# %%
edlevel["ConvertedComp"].mean()
# Out:
# EdLevel
# Associate degree                                                                      146191.275269
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              134966.131508
# I never completed any formal education                                                154087.313636
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           120712.385650
# Other doctoral degree (Ph.D, Ed.D., etc.)                                             171504.379046
# Primary/elementary school                                                              95072.546154
# Professional degree (JD, MD, etc.)                                                     86490.193289
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     85330.023734
# Some college/university study without earning a degree                                117587.731065
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# # 47	Group data by a column, and for each group, calculate the 75th percentile.

# %%
edlevel["ConvertedComp"].describe()
# Out:
#                                                       count           mean  \
# EdLevel
# Associate degree                                     1860.0  146191.275269
# Bachelor’s degree (BA, BS, B.Eng., etc.)            27063.0  134966.131508
# I never completed any formal education                220.0  154087.313636
# Master’s degree (MA, MS, M.Eng., MBA, etc.)         13826.0  120712.385650
# Other doctoral degree (Ph.D, Ed.D., etc.)            1699.0  171504.379046
# Primary/elementary school                             260.0   95072.546154
# Professional degree (JD, MD, etc.)                    745.0   86490.193289
# Secondary school (e.g. American high school, Ge...   2823.0   85330.023734
# Some college/university study without earning a...   6496.0  117587.731065
#
#                                                               std  min  \
# EdLevel
# Associate degree                                    348833.707803  0.0
# ...

# %% [markdown]
# # 48.Group data by a column and calculate the median of a numeric column, excluding outliers

# %%
edlevel["ConvertedComp"].median()
# Out:
# EdLevel
# Associate degree                                                                      56092.5
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              60000.0
# I never completed any formal education                                                53562.0
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           57744.0
# Other doctoral degree (Ph.D, Ed.D., etc.)                                             81960.0
# Primary/elementary school                                                             34368.0
# Professional degree (JD, MD, etc.)                                                    32998.0
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    37128.0
# Some college/university study without earning a degree                                52476.0
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# # 49.

# %%
country_group["LanguageWorkedWith"].apply(lambda x:x .str.contains("Python").sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %% [markdown]
# # 50.

# %%
country_group["LanguageWorkedWith"].apply(lambda x:x .str.contains("HTML").sum())
# Out:
# Country
# Afghanistan                              27
# Albania                                  60
# Algeria                                  89
# Andorra                                   2
# Angola                                    2
#                                        ...
# Venezuela, Bolivarian Republic of...     64
# Viet Nam                                142
# Yemen                                    11
# Zambia                                   10
# Zimbabwe                                 30
# Name: LanguageWorkedWith, Length: 179, dtype: int64
